# %%
from amazon.api import AmazonAPI
import time

f = open("keys.txt", 'r')
AMAZON_ASSOC_TAG = f.readline().strip().split("=")[1]
AMAZON_ACCESS_KEY = f.readline().strip().split("=")[1]
AMAZON_SECRET_KEY = f.readline().strip().split("=")[1]

# %%
amazon = AmazonAPI(AMAZON_ACCESS_KEY, AMAZON_SECRET_KEY, AMAZON_ASSOC_TAG, region="US")

# %%
# smartphone
# samsung smartphone
# oneplus smartphone
# iphone smartphone
# lg smartphone
# htc smartphone
# asus smartphone
# search_terms = ['pet food', 'backpack', 'ps4', 'controller', 'macbook', 'xbox', 'skincare', 'pasta', 'pants',\
#                'shoes', 'harry potter', 'bible', 'adapter', 'makeup']
search_terms = [#'cover', 'sunglasses', 'earrings', 'tape', 'scissors', 'paper', 'camera', 'lipstick', 'hair care',\
               #'jojoba oil', 'lamp', 'lightbulb', 'mug', 'hoodie', 'laptop sleeve', 'keyboard', 'lacquer', \
               'hyaluronic', 'bee', 'pink', 'essential', 'pan', 'bin', 'organizer', 'bed', 'table', 'speaker', 'office', 'oil', 'cream',\
               'sunscreen', 'umbrella', 'salad', 'tuna', 'bird']

# %%
def add_asins_to_examine(search_term):
    
    check = False
    
    while check == False:
        
        time.sleep(3)
        
        try:
            products = amazon.search(Keywords = search_term, SearchIndex='All')

            asins_to_examine = open("asins_to_examine.txt", 'r')
            examined_asins = open("examined_asins.txt", 'r')
            asins_with_problems = open("asins_with_problems.txt", 'r')

            already_added = set()

            for line in asins_to_examine:
                already_added.add(line)
            for line in examined_asins:
                already_added.add(line)
            for line in asins_with_problems:
                already_added.add(line)

            asins_to_examine = open("asins_to_examine.txt", 'a')

            count = 0
            for product in products:
                print product.asin
                count += 1
                if product not in already_added:
                    asins_to_examine.write(product.asin + '\n')
            check = True
            
            print "found " + str(count) + " products for search term " + search_term
            
        except Exception as e:
            print e
            print 'trying again term ' + search_term
            
for word in search_terms:
    add_asins_to_examine(word)
# Out:
# B0090UJFYI
# B01AGHGYN8
# B00L1K7HRC
# B00663G8WO
# B01GUK7NV2
# B003MJ7Z0O
# B01GUK7NVW
# B01M4MCUAF
# B00KB9Q8GU
# B073J5NV5V
# HTTP Error 503: Service Unavailable
# trying again term hyaluronic
# B0090UJFYI
# B01AGHGYN8
# B00L1K7HRC
# B00663G8WO
# B01GUK7NV2
# B003MJ7Z0O
# B01GUK7NVW
# B01M4MCUAF
# B00KB9Q8GU
# B073J5NV5V
# B01N4VMLGA
# B074FHC9WF
# B0013OUKO8
# B00HSFXEYO
# B003C5F8FW
# B00KYUXIOG
# B01N4EL9P9
# B000YJ2SLG
# B00WRIRMOA
# B074XNFD1V
# B000S97MOU
# B0047AKVW6
# B000QS10LY
# B01GUK7NU8
# B00LUA11EI
# B00L0088YE
# B00GT4DL0W
# B00I2495QG
# B000FQUGXA
# B01KMSTCWG
# B00DPE9EQO
# B013HHJV0C
# B00BSNBO9O
# B000UQ4TTW
# B0027EWWIK
# B004R68SBQ
# B06XC5PQGL
# B019UAF6TK
# B015QEPJN2
# B01B5G45R6
# B0119HF4G2
# B0002DH2YW
# B007CKHBM6
# 1423106865
# B01MRV8IQA
# B074T4KNFL
# B074WNX8D1
# B071HLYCL6
# B00IU0E53A
# B002I5NO1C
# B000VOE3QW
# B000SEGI8Q
# B00C61VR2G
# B01AHC6IZG
# B000BLKS5A
# B075SLYB36
# B00LHE5OSQ
# HTTP Error 503: Service Unavailable
# trying again term bird
# B0026HY4HA
# B00YSU3WG2
# B01ARAER10
# B0002DJL4G
# B00WAB0FBG
# 0399563121
# B00CL6IGL6
# B0037UKP9G
# B01COPJX74
# B0171DP33C
# B01G9JU8C0
# B00302DFKM
# B007PO3AEC
# B00F6RCOGA
# B000Z5E4IE
# B003ASLJJK
# B007PO39I4
# B002QNVMLK
# B004VFMMRY
# B013FE9E0E
# B0002DJW3Q
# B01CK7RL9I
# B00S807RIM
# B0119HF4G2
# B0002DH2YW
# B007CKHBM6
# 1423106865
# B01MRV8IQA
# B074T4KNFL
# B074WNX8D1
# B071HLYCL6
# B00IU0E53A
# B002I5NO1C
# B000VOE3QW
# B000SEGI8Q
# B00C61VR2G
# B01AHC6IZG
# B000BLKS5A
# B075SLYB36
# B00LHE5OSQ
# B0056B84X8
# B002KSJPL0
# B0096UUSPC
# B00HW87CB8
# B0012ZX18A
# B000B76OX4
# B00EXIVYQE
# B00629NIMK
# B00TP3H952
# B001MA2ZEQ
# found 50 products for search term bird

# %%
product = amazon.lookup(ItemId='B01LQV1YU6')

# %%
def get_product_dict(product):
    this_dict = {
                'asin':product.asin,
                'actors':product.actors,
                'author':product.author,
                'authors':product.authors,
                'brand':product.brand,
                'color':product.color,
                'creators':product.creators,
                'detail_page_url':product.detail_page_url,
                'ean':product.ean,
                'edition':product.edition,
                'editorial_review':product.editorial_review,
                'editorial_reviews':product.editorial_reviews,
                'eisbn':product.eisbn,
                'features':product.features,
                #'formatted_price':product.formatted_price,
                'genre':product.genre,
                'is_adult':product.is_adult,
                'isbn':product.isbn,
                'label':product.label,
                'languages':list(product.languages),
                'manufactures':product.manufacturer,
                'model':product.model,
                'mpn':product.mpn,
                #'offer_id':product.offer_id,
                'offer_url':product.offer_url,
                'pages':product.pages,
                'parent':product.parent,
                'parent_asin':str(product.parent_asin),
                'part_number':product.part_number,
                'price_and_currency':product.price_and_currency,
                'product_group':product.product_group,
                'product_type_name':product.product_type_name,
                'publication_date':product.publication_date,
                'publisher':product.publisher,
                'region':product.region,
                'release_date':product.release_date,
                #'reviews':product.reviews,
                'reviewTexts':[],
                'running_time':product.running_time,
                'sales_rank':product.sales_rank,
                'sku':product.sku,
                'studio':product.studio,
                'title':product.title,
                'upc':product.upc 
            }
    return this_dict

# %%
import json
import time
import os
import traceback
import logging

f = open("asins_to_examine.txt", 'r')

done_list = set()
for x in os.listdir("product_data"):
    done_list.add(x[:-5])
    
    
for i, line in enumerate(f):

    if line.strip() in done_list: continue
        
    check = False

    while check == False:
        
        time.sleep(3)
        
        try:
            print "trying " + line.strip()
            product = amazon.lookup(ItemId=line.strip())

            this_dict = get_product_dict(product)
            
            if "price_and_currency" in this_dict:
                #print this_dict["price_and_currency"]
                if this_dict["price_and_currency"] != (None, None):
                    this_dict["price_and_currency"] = float(product.price_and_currency[0])
                else: this_dict["price_and_currency"] = ""
                    
            if "release_date" in this_dict and this_dict["release_date"] != None:
                this_dict["release_date"] = this_dict["release_date"].strftime("%Y-%m-%d %H:%M:%S")
                
            if "publication_date" in this_dict and this_dict["publication_date"] != None:
                this_dict["publication_date"] = this_dict["publication_date"].strftime("%Y-%m-%d %H:%M:%S")
            
            if "formatted_price" in this_dict:
                #print this_dict["formatted_price"]
                if this_dict["formatted_price"] != None:
                    this_dict["formatted_price"] = float(product.formatted_price[1:])
                else:
                    this_dict["formatted_price"] = ""
            
            #pprint(this_dict)
            #if "detail_page_url" in this_dict:
            #    this_dict["detail_page_url"] = this_dict["detail_page_url"].split('?')[0]
                
            f_res = open("product_data/"+this_dict['asin']+".json", 'w+')

            json.dump(this_dict, f_res, indent=4)

            check = True
        
        except Exception as e:
            logging.error(traceback.format_exc())
            if "AsinNotFound" in traceback.format_exc(): check = True
            print 'trying again ' + line.strip()
# Out:
# trying B01C9JZEBO
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B01C9JZEBO
# trying B01C9JZEBO
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 183, in lookup
#     etree.tostring(root, pretty_print=True)))
# AsinNotFound: ASIN(s) not found: '<ItemLookupResponse xmlns="http://webservices.amazon.com/AWSECommerceService/2013-08-01">
#   <OperationRequest>
#     <HTTPHeaders>
#       <Header Name="UserAgent" Value="Python-urllib/2.7"/>
#     </HTTPHeaders>
#     <RequestId>bd819339-ee6b-470a-bcee-7370c3d8175a</RequestId>
#     <Arguments>
#       <Argument Name="AWSAccessKeyId" Value="AKIAIRCSTDTCOYE3OA6Q"/>
#       <Argument Name="AssociateTag" Value="picorana-20"/>
#       <Argument Name="ItemId" Value="B01C9JZEBO"/>
#       <Argument Name="Operation" Value="ItemLookup"/>
#       <Argument Name="ResponseGroup" Value="Large"/>
#       <Argument Name="Service" Value="AWSECommerceService"/>
#       <Argument Name="Timestamp" Value="2017-10-21T17:15:06Z"/>
#       <Argument Name="Version" Value="2013-08-01"/>
#       <Argument Name="Signature" Value="g3ecqaBfyvoJD0P7zJOYYyItSRhu86DDbToy8h4xl0w="/>
#     </Arguments>
#     <RequestProcessingTime>0.0341698950000000</RequestProcessingTime>
#   </OperationRequest>
#   <Items>
#     <Request>
#       <IsValid>True</IsValid>
#       <ItemLookupRequest>
#         <IdType>ASIN</IdType>
#         <ItemId>B01C9JZEBO</ItemId>
#         <ResponseGroup>Large</ResponseGroup>
#         <VariationPage>All</VariationPage>
#       </ItemLookupRequest>
#       <Errors>
#         <Error>
#           <Code>AWS.InvalidParameterValue</Code>
#           <Message>B01C9JZEBO is not a valid value for ItemId. Please change this value and retry your request.</Message>
#         </Error>
#       </Errors>
#     </Request>
#   </Items>
# </ItemLookupResponse>
# '
# trying again B01C9JZEBO
# trying B01MS222H9
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 183, in lookup
#     etree.tostring(root, pretty_print=True)))
# AsinNotFound: ASIN(s) not found: '<ItemLookupResponse xmlns="http://webservices.amazon.com/AWSECommerceService/2013-08-01">
#   <OperationRequest>
#     <HTTPHeaders>
#       <Header Name="UserAgent" Value="Python-urllib/2.7"/>
#     </HTTPHeaders>
#     <RequestId>a54d9a89-0230-42cd-8c6c-f4813a69364a</RequestId>
#     <Arguments>
#       <Argument Name="AWSAccessKeyId" Value="AKIAIRCSTDTCOYE3OA6Q"/>
#       <Argument Name="AssociateTag" Value="picorana-20"/>
#       <Argument Name="ItemId" Value="B01MS222H9"/>
#       <Argument Name="Operation" Value="ItemLookup"/>
#       <Argument Name="ResponseGroup" Value="Large"/>
#       <Argument Name="Service" Value="AWSECommerceService"/>
#       <Argument Name="Timestamp" Value="2017-10-21T17:15:10Z"/>
#       <Argument Name="Version" Value="2013-08-01"/>
#       <Argument Name="Signature" Value="DX/ASLbyhI+sy0XsnD9qZngBJN3m1j02Sm7eAkc0Hos="/>
#     </Arguments>
#     <RequestProcessingTime>0.0416825070000000</RequestProcessingTime>
#   </OperationRequest>
#   <Items>
#     <Request>
#       <IsValid>True</IsValid>
#       <ItemLookupRequest>
#         <IdType>ASIN</IdType>
#         <ItemId>B01MS222H9</ItemId>
#         <ResponseGroup>Large</ResponseGroup>
#         <VariationPage>All</VariationPage>
#       </ItemLookupRequest>
#       <Errors>
#         <Error>
#           <Code>AWS.InvalidParameterValue</Code>
#           <Message>B01MS222H9 is not a valid value for ItemId. Please change this value and retry your request.</Message>
#         </Error>
#       </Errors>
#     </Request>
#   </Items>
# </ItemLookupResponse>
# '
# trying again B01MS222H9
# trying B0056E655E
# trying B004AFVEOC
# trying B01G1NHAYI
# trying B00C3NPY44
# trying B01LQV1YU6
# trying B06XW6SJF8
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B06XW6SJF8
# trying B06XW6SJF8
# trying B074379C84
# trying B01I9JRP1A
# trying B0747K6ZQM
# trying B01LQV1YHO
# trying B00W94246I
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B00W94246I
# trying B00W94246I
# trying B00W94246I
# trying B072KLZW6N
# trying B01N5RGLOP
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B01N5RGLOP
# trying B01N5RGLOP
# trying B015AH8TQE
# trying B01ANFTFV6
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B01ANFTFV6
# trying B01ANFTFV6
# trying B01AFZ3MLS
# trying B01IRUBO18
# trying B015ZKK2ES
# trying B00VWKKHKU
# trying B00VWKKHE6
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B00VWKKHE6
# trying B00VWKKHE6
# trying B01IRTZUU0
# trying B0186S41RU
# trying B00I7EM752
# trying B01IB9H9MS
# trying B073XW4JHC
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B073XW4JHC
# trying B073XW4JHC
# trying B071XF4DTG
# trying B01LX7T4O3
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B01LX7T4O3
# trying B01LX7T4O3
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B01LX7T4O3
# trying B01LX7T4O3
# trying B00TXR59J8
# trying B014QR96G6
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B014QR96G6
# trying B014QR96G6
# trying B01LQV1YNS
# trying B06X3Q5K3V
# trying B00L8UVLOA
# trying B01MZ46E4F
# trying B00120LA4C
# trying B00TCVHGZU
# trying B01I9JM23G
# trying B019DT8GMC
# trying B0186S41XE
# trying B01B2MSEG6
# trying B018XGSG8K
# trying B0158G8KJ8
# trying B014UT5948
# trying B00W6TZZJY
# trying B00KX8OL8G
# trying B01FVQM8ZM
# trying B00W3NHOX8
# trying B01LQX5N56
# trying B01N3TNH8D
# trying B01M35B7LZ
# trying B01N8S05X9
# trying B0090UJFYI
# trying B01AGHGYN8
# trying B00L1K7HRC
# trying B00663G8WO
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B006TOJLX8
# trying B006TOJLX8
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B006TOJLX8
# trying B006TOJLX8
# trying B005NB1I9S
# trying B06X9MLD9D
# trying B06ZYKBFQC
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B06ZYKBFQC
# trying B06ZYKBFQC
# trying B004U4EBPW
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B004U4EBPW
# trying B004U4EBPW
# trying B01HOUELEO
# trying B00JJ30KHM
# trying B003GOWPO6
# trying B016CJRHR6
# trying B01CEZI40Q
# trying B00DTEV54Y
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B00DTEV54Y
# trying B00DTEV54Y
# ERROR:root:Traceback (most recent call last):
#   File "<ipython-input-22-10b972dc846d>", line 26, in <module>
#     product = amazon.lookup(ItemId=line.strip())
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.py", line 174, in lookup
#     response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 265, in __call__
#     {'api_url': api_url, 'cache_url': cache_url})
#   File "/home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.py", line 226, in _call_api
#     return urllib2.urlopen(api_request, timeout=self.Timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 154, in urlopen
#     return opener.open(url, data, timeout)
#   File "/usr/lib/python2.7/urllib2.py", line 435, in open
#     response = meth(req, response)
#   File "/usr/lib/python2.7/urllib2.py", line 548, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/usr/lib/python2.7/urllib2.py", line 473, in error
#     return self._call_chain(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 407, in _call_chain
#     result = func(*args)
#   File "/usr/lib/python2.7/urllib2.py", line 556, in http_error_default
#     raise HTTPError(req.get_full_url(), code, msg, hdrs, fp)
# HTTPError: HTTP Error 503: Service Unavailable
# trying again B00DTEV54Y
# trying B00DTEV54Y
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-10b972dc846d> in <module>()
#      24         try:
#      25             print "trying " + line.strip()
# ---> 26             product = amazon.lookup(ItemId=line.strip())
#      27
#      28             this_dict = get_product_dict(product)
#
# /home/rana/Envs/amazon/local/lib/python2.7/site-packages/amazon/api.pyc in lookup(self, ResponseGroup, **kwargs)
#     172             items where returned.
#     173         """
# --> 174         response = self.api.ItemLookup(ResponseGroup=ResponseGroup, **kwargs)
#     175         root = objectify.fromstring(response)
#     176         if root.Items.Request.IsValid == 'False':
#
# /home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.pyc in __call__(self, **kwargs)
#     263         # make the actual API call
#     264         response = self._call_api(api_url,
# --> 265                                   {'api_url': api_url, 'cache_url': cache_url})
#     266
#     267         # decompress the response if need be
#
# /home/rana/Envs/amazon/local/lib/python2.7/site-packages/bottlenose/api.pyc in _call_api(self, api_url, err_env)
#     224                 else:
#     225                     # the simple way
# --> 226                     return urllib2.urlopen(api_request, timeout=self.Timeout)
#     227             except:
#     228                 if not self.ErrorHandler:
#
# /usr/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /usr/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# /usr/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# /usr/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /usr/lib/python2.7/urllib2.pyc in https_open(self, req)
#    1239         def https_open(self, req):
#    1240             return self.do_open(httplib.HTTPSConnection, req,
# -> 1241                 context=self._context)
#    1242
#    1243         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1199         else:
#    1200             try:
# -> 1201                 r = h.getresponse(buffering=True)
#    1202             except TypeError: # buffering kw not supported
#    1203                 r = h.getresponse()
#
# /usr/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# /usr/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# /usr/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /usr/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     754                     "non-zero flags not allowed in calls to recv() on %s" %
#     755                     self.__class__)
# --> 756             return self.read(buflen)
#     757         else:
#     758             return self._sock.recv(buflen, flags)
#
# /usr/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     641                 v = self._sslobj.read(len, buffer)
#     642             else:
# --> 643                 v = self._sslobj.read(len)
#     644             return v
#     645         except SSLError as x:
#
# KeyboardInterrupt:

# %%
import json
import traceback

data = []

no_asin = set()
yes_asin = set()

data = {}

output = open("output.json", 'w')

with open('Cell_Phones_and_Accessories_5.json', 'r') as f:
    
    for i, line in enumerate(f):
        
        if i%100==0: print i, len(data)
        
        d = json.loads(line)
        if d['asin'] in no_asin: continue
            
        if d['asin'] in yes_asin: 
            data[d['asin']]['reviewTexts'].append(d['reviewText'])
            
        try:
            product = amazon.lookup(ItemId=d['asin'])
            
            yes_asin.add(d['asin'])
                           
            this_dict = {}
     
            this_dict['features'] = product.features
            this_dict['brand'] = product.brand
            this_dict['label'] = product.label

            this_dict['reviewTexts'] = []
            this_dict['reviewTexts'].append(d['reviewText'])
                
            data[d['asin']] = this_dict

        except Exception as e:
            print traceback.format_exc()
            no_asin.add(d['asin'])

# %%
this_dict = {
                'actors':product.actors,
                'author':product.author,
                'authors':product.authors,
                'brand':product.brand,
                'color':product.color,
                'creators':product.creators,
                'detail_page_url':product.detail_page_url,
                'ean':product.ean,
                'edition':product.edition,
                'editorial_review':product.editorial_review,
                'editorial_reviews':product.editorial_reviews,
                'eisbn':product.eisbn,
                'features':product.features,
                'formatted_price':product.formatted_price,
                'genre':product.genre,
                'get_attribute':product.get_attribute,
                'get_attribute_details':product.get_attribute_details,
                'get_attributes':product.get_attributes,
                'is_adult':product.is_adult,
                'isbn':product.isbn,
                'label':product.label,
                'languages':product.languages,
                'list_price':product.list_price,
                'manufactures':product.manufacturer,
                'model':product.model,
                'mpn':product.mpn,
                'offer_id':product.offer_id,
                'offer_url':product.offer_url,
                'pages':product.pages,
                'parent':product.parent,
                'parent_asin':product.parent_asin,
                'part_number':product.part_number,
                'price_and_currency':product.price_and_currency,
                'product_group':product.product_group,
                'product_type_name':product.product_type_name,
                'publication_date':product.publication_date,
                'publisher':product.publisher,
                'region':product.region,
                'release_date':product.release_date,
                'reviews':product.reviews,
                'reviewTexts':[],
                'running_time':product.running_time,
                'sales_rank':product.sales_rank,
                'sku':product.sku,
                'studio':product.studio,
                'title':product.title,
                'to_string':product.to_string,
                'upc':product.upc 
            }

# %%
from pprint import pprint
#pprint(this_dict)
print product.name

# %%
import urllib2
from bs4 import BeautifulSoup

proxy = urllib2.ProxyHandler({'https': '103.249.180.163'})
opener = urllib2.build_opener(proxy)
urllib2.install_opener(opener)
res = urllib2.urlopen('https://www.amazon.com/gp/product/B01H2E0J5M').read()

print res

# %%
import requests
#url = 'https://www.amazon.com/gp/product/B01H2E0J5M'
url = 'https://www.amazon.com/BLU-R1-HD-Exclusive-Lockscreen/product-reviews/B01H2E0J5M'
proxy = '103.249.180.163'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
res = requests.get(url, proxies={"http":proxy}, headers=headers)

print res.content

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.content, 'html.parser')
divs = soup.findAll("span", { "class" : "review-text" })
for d in divs: 
    print d
#print soup.prettify()
